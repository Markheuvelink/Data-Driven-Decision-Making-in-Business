# %%
# This is a code cell, and this line is a comment, which is ignored by Python
5+15/3
# Out:
# 10.0

# %% [markdown]
# This is a markdown cell in which you can write text. Markdown cells use Markdown formatting.

# %% [markdown]
# ## About markdown cells
# Markdown cells use markdown formatting for formatting the text. This makes text more readable and visually structured without relying on complex formatting menus or software. Some common  Markdown formatting examples are:
#
# # Heading 1
# ## Heading 2
# ### Heading 3 etc.
# **Bold text**
#
# *Italic text*
#
# ***Bold italic text***
#
# > Item in an enumeration
#
# When you are done editing, click on the checkmark at the top right of the cell. The text will now appear with Markdown formatting in your notebook.

# %%
print(8/2)
print(15^4)
print(15*4)
# Out:
# 4.0
# 11
# 60

# %%
print(6*5-2*10/4)       #Door de Hashtag ziet de code dit niet(Hiernaast mist er een () in de eerste formule, voor een ander resultaat)
print((6*5-2*10)/4)
print(( 6 * 5 - 2 * 10 )/4)
print((6*5-2*10)/4)
# Out:
# 25.0
# 2.5
# 2.5
# 2.5

# %%
print("Test")
print('test5') #Gebruikt het liefst alleen "" of ''. want dan kan je dit geheel door gebruiken, hierdoor minder verwarring
# Out:
# Test
# test5

# %%
type(3.1)
# Out:
# float

# %%
x=8
print(x)
print("x") #omdat er "" staan komt er x uit
10*x*5
# Out:
# 8
# x
# 400

# %%
#option 1
c=2
z=c+1
print(z)
# Out:
# 3

# %%
#option 2 (Deze werkt niet want python leest van boven naar beneden) Let op als c=waarde al voor is gekomen neemt die dat hier mee!!!!
D=F+1
print(D)
F=2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 #option 2 (Deze werkt niet want python leest van boven naar beneden) Let op als c=waarde al voor is gekomen neemt die dat hier mee!!!!
# ----> 2 D=F+1
#       3 print(D)
#       4 F=2
#
# NameError: name 'F' is not defined

# %%
name="Jenny"
age= 15 + 25

print(f"Hi, my name is {name} and my age is {age}")
# Out:
# Hi, my name is Jenny and my age is 40

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [10,15,13,18,12]

plt.plot(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Simple graph")

plt.show()

# %%
age=int(input(22))

if age <12: 
    price = 8
elif age <65:
    price = 10
else: price = 9

print(f"Your ticker price is ${price}.")

# %%
age = int(input("Enter your age: "))  # Corrected input prompt

if age < 12: 
    price = 8
elif age < 65:
    price = 10
else: 
    price = 9

print(f"Your ticket price is ${price}.")
# Out:
# Your ticket price is $10.

# %%
for letter in "Yes":
    print(letter)
print("Done!")
# Out:
# Y
# e
# s
# Done!

# %%
for number in range(1,6): #6 wordt niet meegenomen met range. Rechterkant neemt die niet mee
    print(f"This is number {number}")
print("Done!")
# Out:
# This is number 1
# This is number 2
# This is number 3
# This is number 4
# This is number 5
# Done!

# %%
def bye():              #Het maken van een functie in python die wordt opgeslagen
    print("Goodbye!")

print("Hello")

bye()
# Out:
# Hello
# Goodbye!

# %%
def calculate_area (lenght, width)
    area = lenght * width
    return area

my_area = calculate_area(5,10)
print(f"The area is: {my_area}")
# Out:
#   Cell In[12], line 1
#     def calculate_area (lenght, width)
#                                       ^
# SyntaxError: expected ':'

# %%
list= ["Mark","Lisa","Daan"]
for text in list:
    print(f"Hello, {text}")
# Out:
# Hello, Mark
# Hello, Lisa
# Hello, Daan

# %%
for text in range("Daan", "Mark", "Test"): #6 wordt niet meegenomen met range. Rechterkant neemt die niet mee
    print(f"Hello, {number}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 for text in range("Daan", "Mark", "Test"): #6 wordt niet meegenomen met range. Rechterkant neemt die niet mee
#       2     print(f"Hello, {number}")
#
# TypeError: 'str' object cannot be interpreted as an integer
